# %%
import re
import fitz

def check_stt_title_conditions_EU_2022(span_dict):
    if span_dict['font'] == "OpenSans-Bold" and span_dict['size'] == 10.5 and span_dict['color'] == 0 and not bool(re.search(r'\d\.\d',span_dict['text'])):
        return True
    return False

def check_stt_title_conditions_EU_2023(span_dict):
    if span_dict['font'] == "Calibri-Bold" and span_dict['size'] == 12.0 and span_dict['color'] == 0:
        return True
    return False

def check_stt_description_conditions_EU_2022(span_dict):
    if span_dict['font'] == "OpenSans" and (span_dict['size'] == 10.5 or span_dict['size'] == 10.0) and span_dict['color'] == 0:
        return True
    return False

def check_stt_description_conditions_EU_2023(span_dict):
    if span_dict['font'] == "Calibri" and (span_dict['size'] == 12.0 or span_dict['size'] == 10.0) and span_dict['color'] == 0:
        return True
    return False

def check_stt_url_conditions_EU_2022(span_dict):
    if span_dict['font'] == "OpenSans-Light" and span_dict['size'] == 10.5 and span_dict['color'] == 1393044:
        return True
    return False

def check_stt_url_conditions_EU_2023(span_dict):
    if span_dict['font'] == "Calibri" and span_dict['size'] == 12.0 and span_dict['color'] == 287681:
        return True
    return False


class STT:

    def __init__(self, title, bbox, initial_pdf_page):
        tmp = []
        if ";" in title:
            tmp = title.split(";")
        elif "," in title:
            tmp = title.split(",")
        self.name = tmp[0] if len(tmp) > 1 else title
        self.city = "" if len(tmp) <= 1 else tmp[-1].replace(":", "")[1:]
        self.description = ""
        self.urls = []
        self.images = []
        self.y = float(bbox[1])
        self.initial_pdf_page = initial_pdf_page
        self.final_pdf_page = initial_pdf_page

    def set_description(self, description, current_pdf_page):
        if self.description != "" and description[0] != " " and self.description[-1] == ".":
            self.description += "\n"
        self.description += description
        self.set_final_pdf_page(current_pdf_page)


    def set_url(self, url, current_pdf_page):
        # print(f"Set url for {stt.name}. Current page: {current_pdf_page}")
        if url == " ": return
        if url.startswith("http") or url.startswith("www"):
            self.urls.append(url)
        else:
            self.urls[-1] += url
        self.set_final_pdf_page(current_pdf_page)

    def set_image(self, image_data):
        self.images.append(image_data)
        
    def set_final_pdf_page(self, final_pdf_page):
        self.final_pdf_page = final_pdf_page

    def __str__(self):
        return f"\nSTT: {self.name}\nDescription: {self.description}\nURL: {self.urls}\nNumber of images: {len(self.images)}\nCity: {self.city}\nInitial page:{self.initial_pdf_page}\nFinal page:{self.final_pdf_page}"

stts_founded = []

def append_stt(span_dict, pag_number):
    stts_founded.append(STT(span_dict['text'], span_dict['bbox'], pag_number))
    
def remove_chars_from_city(city):
    return city.replace(":", "").replace(" ", "")


def span_is_title(span_dict, pag_number):
    # Caso o título esteja dividido em vários spans
    if len(stts_founded) > 0 and stts_founded[-1].description == "":
        # Resolver caso de Venice pag 12
        if (":" in span_dict['text'] and ";" in span_dict['text'] 
                and float(span_dict['bbox'][1]) - stts_founded[-1].y > 16.00):
            # A distância entre linhas consecutivas é +/- 15.00
            stts_founded.remove(stts_founded[-1])
            append_stt(span_dict, pag_number)
        # Irá entrar no ELIF caso o current span conter a cidade
        elif ":" in span_dict['text']:
            if ";" in span_dict['text']:
                tmp = span_dict['text'].split(";")
                stts_founded[-1].name += tmp[0]
                stts_founded[-1].city = remove_chars_from_city(tmp[1])
            elif "," in span_dict['text']:
                tmp = span_dict['text'].split(",")
                stts_founded[-1].name += tmp[0]
                stts_founded[-1].city = remove_chars_from_city(tmp[1])
            else:
                stts_founded[-1].name = stts_founded[-1].name.replace(";", "")
                stts_founded[-1].city = remove_chars_from_city(span_dict['text'])
        else: stts_founded[-1].name += span_dict['text']
    else: append_stt(span_dict, pag_number)
    
def analyze_span_EU_2022(span_dict, pag_number):
    print("span_dict: ", span_dict)
    if check_stt_title_conditions_EU_2022(span_dict):
        span_is_title(span_dict, pag_number)
        # Caso contenha descrição de uma STT que termine na primeira página deste PDF
    elif len(stts_founded) == 0:
        return
    elif check_stt_description_conditions_EU_2022(span_dict):
        # print(f"Description founded: {span['text']}")
        stts_founded[-1].set_description(span_dict['text'], pag_number)
    elif check_stt_url_conditions_EU_2022(span_dict):
        # print(f"URL founded: {span['text']}")
        stts_founded[-1].set_description(span_dict['text'], pag_number)
        stts_founded[-1].set_url(span_dict['text'], pag_number)
        
def analyze_span_EU_2023(span_dict, pag_number):
    # print("span_dict: ", span_dict)
    if span_dict['font'] == "Calibri" and span_dict['size'] != 12.0 and span_dict['color'] == 0:
        print(f"New description size: {span_dict['size']}, {span_dict['text']}")
    if check_stt_title_conditions_EU_2023(span_dict):
        span_is_title(span_dict, pag_number)
        # Caso contenha descrição de uma STT que termine na primeira página deste PDF
    elif len(stts_founded) == 0:
        return
    elif check_stt_description_conditions_EU_2023(span_dict):
        # print(f"Description founded: {span['text']}")
        stts_founded[-1].set_description(span_dict['text'], pag_number)
    elif check_stt_url_conditions_EU_2023(span_dict):
        # print(f"URL founded: {span['text']}")
        stts_founded[-1].set_description(span_dict['text'], pag_number)
        stts_founded[-1].set_url(span_dict['text'], pag_number)
        
def find_correspondent_stt_to_image(img_block, current_page_number):
    for stt_founded in reversed(stts_founded):
        if current_page_number == stt_founded.initial_pdf_page and stt_founded.y < img_block['bbox'][1]:
            return stt_founded
    """
    If doesn't find a correspondent STT in the current page, it means that the image belongs to the last stt_founded
    in the previous page
    """
    for stt_founded in reversed(stts_founded):
        if current_page_number - 1 == stt_founded.initial_pdf_page:
            return stt_founded

# %%
eu_2022 = "../Catalogues/Catalogue European.pdf"

stts_founded = []
with fitz.open(eu_2022) as doc:
    for page_number in range(7, 8):
        page = doc[page_number]
        for block in page.get_text('dict')['blocks']:
            # print(block)
            if "lines" in block.keys():
                for line in block['lines']:
                    for span in line['spans']:
                        analyze_span_EU_2022(span, page_number)
            elif block['type'] == 1:
                # Caso o block da image não apareca por ordem
                if len(stts_founded) > 0 and stts_founded[-1].y < block['bbox'][1]:
                    stts_founded[-1].set_image(block['image'])
                else:
                    print(f"Number of STT founded: {len(stts_founded)}")
                    stts_founded[-2].set_image(block['image'])

# %%
eu_2023 = "../Catalogues/2023-leading-practices-in-smart-tourism.pdf"
logo_to_ignore_EU2023 = open(f"logo_to_ignore.jpg", "rb").read()
eu_to_ignore_EU2023 = open(f"EU_logo_to_ignore.jpg", "rb").read()

stts_founded = []
with fitz.open(eu_2023) as doc:
    for page_number in range(7, 72):
        print(f"Page number: {page_number}")
        page = doc[page_number]
        for block in page.get_text('dict')['blocks']:
            # print(block)
            if "lines" in block.keys():
                for line in block['lines']:
                    for span in line['spans']:
                        try:
                            int(span['text'])
                        except ValueError:
                            analyze_span_EU_2023(span, page_number)
            elif block['type'] == 1:
                if block['image'] == logo_to_ignore_EU2023 or block['image'] == eu_to_ignore_EU2023:
                    # print("Ignored image")
                    continue
                # Caso o block da image não apareca por ordem
                else: find_correspondent_stt_to_image(block,page_number).set_image(block['image'])
# Out:
# Page number: 7
# Page number: 8
# New description size: 11.039999961853027, © City of Antalya
# New description size: 11.039999961853027, © City of Gdynia
# Page number: 9
# New description size: 11.039999961853027, © City of Gdynia
# New description size: 11.039999961853027, © City of Gijón
# Page number: 10
# New description size: 11.039999961853027, © City of Pafos
# New description size: 11.039999961853027, © City of San Sebastián
# Page number: 11
# New description size: 11.039999961853027, © Visit Cork
# Page number: 12
# New description size: 11.039999961853027, © City of Essen
# Page number: 13
# Page number: 14
# New description size: 11.039999961853027, National Rugby Stadium, © City of Gdynia
# Page number: 15
# New description size: 9.119999885559082,
# New description size: 11.039999961853027, © Taranto Municipality
# New description size: 11.039999961853027,
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# Page number: 16
# New description size: 11.039999961853027, © City of Gijón
# Page number: 17
# New description size: 11.039999961853027, © City of San Sebastián
# New description size: 11.039999961853027, © City of Gijón
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# Page number: 18
# New description size: 9.119999885559082,
# New description size: 11.039999961853027, © City of Pafos
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# Page number: 19
# New description size: 11.039999961853027, © City of Efeler
# Page number: 20
# New description size: 11.039999961853027, © Visit Cork
# New description size: 11.039999961853027, © Andrea via AdobeStock
# New description size: 9.119999885559082,
# Page number: 21
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 11.039999961853027, © City of Kaunas
# Page number: 22
# New description size: 11.039999961853027, © Lublin Municity Office
# Page number: 23
# New description size: 11.039999961853027, © Taranto Municipality
# Page number: 24
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# Page number: 25
# New description size: 11.039999961853027, © City of Genoa
# Page number: 26
# New description size: 9.119999885559082,
# Page number: 27
# New description size: 11.039999961853027, © Filippa Brito / CM Porto
# Page number: 28
# New description size: 9.119999885559082,
# Page number: 29
# New description size: 9.119999885559082,
# Page number: 30
# New description size: 11.039999961853027, © City of San Sebastián
# Page number: 31
# Page number: 32
# New description size: 11.039999961853027, © City of Pafos
# Page number: 33
# New description size: 11.039999961853027, © City of Efeler
# New description size: 11.039999961853027, © City of Gdynia
# Page number: 34
# New description size: 11.039999961853027, © R.T.P. Land Italia Srl – Sgobba – Lorusso – Alfino
# Page number: 35
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 11.039999961853027, © City of Antalya
# Page number: 36
# New description size: 11.039999961853027, © City of Aarhus
# New description size: 11.039999961853027, © City of Genoa
# Page number: 37
# New description size: 11.039999961853027, © City of San Sebastián
# Page number: 38
# New description size: 11.039999961853027, © City of Antalya
# Page number: 39
# New description size: 11.039999961853027, © Visit Cork
# New description size: 11.039999961853027, © City of Essen
# Page number: 40
# New description size: 11.039999961853027, © Lublin Municity Office
# Page number: 41
# New description size: 11.039999961853027, © City of Pafos
# Page number: 42
# New description size: 11.039999961853027, © City of Aarhus
# Page number: 43
# New description size: 11.039999961853027, © City of Genoa
# Page number: 44
# Page number: 45
# New description size: 11.039999961853027, © City of Gijón
# New description size: 11.039999961853027, © Lublin Municity Office
# Page number: 46
# New description size: 11.039999961853027, © City of Pafos
# New description size: 7.919999599456787, th
# Page number: 47
# New description size: 11.039999961853027, © City of Gdynia
# Page number: 48
# Page number: 49
# New description size: 11.039999961853027, © City of San Sebastián
# Page number: 50
# New description size: 11.039999961853027, © City of Antalya
# Page number: 51
# Page number: 52
# New description size: 11.039999961853027, © Background Photo Sandis
# Page number: 53
# New description size: 7.919999599456787, th
# Page number: 54
# New description size: 11.039999961853027, © City of Efeler
# Page number: 55
# New description size: 11.039999961853027, © Filippa Brito / CM Porto
# Page number: 56
# New description size: 11.039999961853027, © City of Antalya
# Page number: 57
# New description size: 11.039999961853027, © City of Konya
# New description size: 11.039999961853027, © City of Pafos
# Page number: 58
# Page number: 59
# New description size: 11.039999961853027, © Raisfoto / City of Aarhus
# Page number: 60
# New description size: 11.039999961853027, © City of Pafos
# New description size: 11.039999961853027, © Cosimo Calabrese
# Page number: 61
# New description size: 7.919999599456787, th
# New description size: 7.919999599456787, th
# Page number: 62
# New description size: 11.039999961853027, © City of Aarhus
# Page number: 63
# New description size: 11.039999961853027, Danuta Baduszkowa Music Theatre, © City of Gdynia
# New description size: 11.039999961853027, © City of San Sebastián
# Page number: 64
# Page number: 65
# New description size: 11.039999961853027, © City of Essen
# New description size: 11.039999961853027, © City of Kaunas
# Page number: 66
# New description size: 11.039999961853027, © City of Antalya
# Page number: 67
# New description size: 11.039999961853027, © City of Gijón
# New description size: 11.039999961853027, © City of Genoa
# Page number: 68
# New description size: 11.039999961853027, © City of Gdynia
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# New description size: 9.119999885559082,
# Page number: 69
# Page number: 70
# New description size: 11.039999961853027, © Visit Cork
# New description size: 11.039999961853027, © City of Genoa
# Page number: 71
# New description size: 11.039999961853027, © City of Gijón
# New description size: 11.039999961853027, © City of San Sebastián

# %%
for stt in stts_founded:
    print(stt)
# Out:
# STT: Inclusive initiatives
# Description: Accessibility is also about inclusion and Aarhus is an open and innovative city with a great diversity of people. Aarhus has a strong LGBTQ+ community and every year, the Aarhus Pride parade celebrates diversity in Aarhus and contributes to the respect for and acceptance of all LGBTQ+ persons. Also, the Aarhus City Council has a strong focus on making Aarhus a better and more attractive city and a better and more attractive workplace for LGBTQ+ persons. As the first city in Denmark, Aarhus in 2019 joined the Rainbow Cities Network, including 33 cities in 17 different countries, actively working to improve conditions for LGBTQ+ citizens. Aarhus also hosts ‘KØN – Gender Museum Denmark’ presenting the cultural history between genders, equality, body and sexuality. A comprehensive policy of the City entitled ‘Aarhus for us all’ is addressing accessibility issues for people with special needs. The policy reflects the fact that the City has a holistic approach to creating an accessible environment for everyone, with a focus on people with disabilities. Aarhus wants everyone to feel valued and have equal opportunities when it comes to making use of the city. Based on the City’s three values, Reliability, Respect, and Commitment, Aarhus wants to ensure that people with all types of disabilities are given the option to live an independent life and opportunities to participate on their own terms.   Find out more at: https://www.aarhus.dk/english/collaborate-with-the-city/inclusive-citizenship/inclusion/
# URL: ['https://www.aarhus.dk/english/collaborate-with-the-city/inclusive-citizenship/inclusion/']
# Number of images: 0
# City: Aarhus
# Initial page:7
# Final page:7
#
# STT: Acoustic Pedestrian Warning Device System
# Description: The Acoustic Pedestrian Warning Device System applications were implemented at the intersections in different parts of the city in Antalya. It aims to make the pedestrian crossings at signalised intersections safer and available for independent use for the visually impaired and elderly people. With the Acoustic Pedestrian Warning Device, when the pedestrian signal transmitters change colour, audible messages are given to the pedestrians, allowing them to cross the street or wait. When the pedestrians come to the pedestrian crossing, when they show their hand from 5cm distance or touch, the system sends a request for a pedestrian crossing to the intersection device. When the time given for crossing the road is completed, the beep sound indicated for the red light will be activated and this warning will continue until the request button is pressed again. In addition, warnings in touristic areas are made in English.        Find out more at: https://raillynews.com/2020/12/Traffic-lights-will-speak-for-the-visually-impaired-in-Antalya/
# URL: ['https://raillynews.com/2020/12/Traffic-lights-will-speak-for-the-visually-impaired-in-Antalya/\u202f\u202f']
# Number of images: 1
# City: Antalya
# Initial page:7
# Final page:8
#
# STT: Accessible and Safe celebrations
# Description:  The city of Seville celebrates and hosts some of the most popular events around the world with millions of visitors allowing the public spaces to be transformed and explored. As a consequence, Seville has adopted a series of accessibility measures such as integrated maps and routes that are available on the SEVILLE ACCESSIBLE app as well as accessible signage at events. A prime example of such measures is the Feria de Abril event that also has noiseless schedules and accessible attractions to provide an opportunity for everyone to enjoy these festivities.
# URL: []
# Number of images: 0
# City: Seville
# Initial page:8
# Final page:8
#
# STT: Accessible beaches / Disabled Friendly Beaches
# Description: Antalya has 231 blue flagged beaches and 42 of them are fully accessible to disabled which has special wheelchair sunbeds and 189 beaches are partly disabled friendly.      Find out more at: https://www.mobilityturkey.com/wheelchair-accessible-holiday-antalya
# URL: ['https://www.mobilityturkey.com/wheelchair-accessible-holiday-antalya']
# Number of images: 1
# City: Antalya
# Initial page:8
# Final page:8
#
# STT: Facilitated beach access for people with disabilities
# Description: Entrances to the city center beach are equipped with posts for the blind with pictograms and Braille description of the   direction which is facilitated by wooden ramps. A playground with equipment for children with disabilities is also provided along with umbrellas for sun protection. The city center beach offers toilets and showers for people with disabilities and people with mobility impairments can take advantage of bathing chairs at the bathing site (so-called amphibian). Gdynia's beaches provide accessibility audits describing and illustrating access to them. The city’s lifeguards have been trained to communicate with people with sight, hearing or multiple disabilities and have trained methods and techniques for transferring, supporting and assisting people at the bathing sites.      Find out more at: https://www.inyourpocket.com/gdansk/travelling-with-a-disability-in-gdansk-sopot_77157f
# URL: ['https://www.inyourpocket.com/gdansk/travelling-with-a-disability-in-gdansk-sopot_77157f']
# Number of images: 1
# City: Gdynia
# Initial page:8
# Final page:9
#
# STT: Accessibility on the Poniente Beach
# Description: The Poniente Beach in Gijón offers an accessible area for people with disabilities. Operational since 2015, many facilities are available, such as two adapted toilets and showers, an accessible beach library, amphibious chairs and crutches, and the Audioplaya support system.     Find out more at: https://en.asturias.com/west-beach/
# URL: ['https://en.asturias.com/west-beach/']
# Number of images: 1
# City: Gijón
# Initial page:9
# Final page:9

# %%
# Import to Omeka
from OmekaAPI import OmekaAPI
from OmekaAPI import EU_CATALOGUE_2022, EU_CATALOGUE_2023
from OmekaAPI import STT_APPLICATION_TYPE

omeka = OmekaAPI('https://sttobservatory.omeka.net', '80474f200ef8d2ae09caab85d5b03761435b1318')
# src_pdf = fitz.open("../Catalogues/Catalogue European.pdf")
src_pdf = fitz.open("../Catalogues/2023-leading-practices-in-smart-tourism.pdf")
# stts_folder = "../EU_2022"
stts_folder = "../EU_2023"

# Choose between EU_2022 folder or EU_2023 folder
for stt_index, stt in enumerate(stts_founded):
    if stt.city != "":
        stt_pdf = fitz.open()
        
        stt_pdf.insert_pdf(src_pdf, from_page=stt.initial_pdf_page, to_page=stt.final_pdf_page)
        
        stt_name_without_special_chars = stt.name.replace("/","").replace("\"","")
        
        stt_pdf_name = f"{stts_folder}/{stt.initial_pdf_page}_{stt_name_without_special_chars}.pdf".replace(":","")
                
        stt_pdf.save(stt_pdf_name)
    
        item_id = omeka.post_item(
            title=stt.name,
            description=stt.description,
            item_type=STT_APPLICATION_TYPE,
            urls=stt.urls,
            collection=omeka.get_collection_id_by_name(EU_CATALOGUE_2023),
            address=stt.city
        )
    
        for index, image in enumerate(stt.images):
            omeka.post_file_for_item(item_id, f"{stt.name}_{index}.jpg", image)
        
        with open(stt_pdf_name, 'rb') as f:
            omeka.post_file_for_item(item_id, stt_pdf_name, f.read())
    
        try:
            omeka.post_geolocation_for_item(stt.city,item_id)
        except AttributeError:
            continue
# Out:
# Post Item for Inclusive initiatives, 355: Created
# Post File to Item 355: Created
# Post Geolocation to Item 355: Created
#
# Post Item for Acoustic Pedestrian Warning Device System, 356: Created
# Post File to Item 356: Created
# Post File to Item 356: Created
# Post Geolocation to Item 356: Created
#
# Post Item for Accessible and Safe celebrations, 357: Created
# Post File to Item 357: Created
# Post Geolocation to Item 357: Created
#
# Post Item for Accessible beaches / Disabled Friendly Beaches, 358: Created
# Post File to Item 358: Created
# Post File to Item 358: Created
# Post Geolocation to Item 358: Created
#
# Post Item for Facilitated beach access for people with disabilities, 359: Created
# Post File to Item 359: Created
# Post File to Item 359: Created
# Post Geolocation to Item 359: Created
#
# Post Item for Accessibility on the Poniente Beach, 360: Created
# Post File to Item 360: Created
# Post File to Item 360: Created
# Post Geolocation to Item 360: Created
#
# Post Item for Making Beaches Accessible, 361: Created
# Post File to Item 361: Created
# Post File to Item 361: Created
# Post Geolocation to Item 361: Created
#
# Post Item for La Concha Beach, assisted bathing service, 362: Created
# Post File to Item 362: Created
# Post File to Item 362: Created
# Post Geolocation to Item 362: Created
#
# Post Item for Accessibility Guide by Visit Cork, 363: Created
# Post File to Item 363: Created
# Post File to Item 363: Created
# Post Geolocation to Item 363: Created
#
# Post Item for Sign Language Guided Tours for Christmas Market, 364: Created
# Post File to Item 364: Created
# Post File to Item 364: Created
# Post Geolocation to Item 364: Created
#
# Post Item for informing about accessibility of tourist sites, 365: Created
# Post File to Item 365: Created
# Post Geolocation to Item 365: Created
#
# Post Item for “Padova per tutti” Project, 366: Created
# Post File to Item 366: Created
# Post Geolocation to Item 366: Created
#
# Post Item for A new information tool on accessibility, 367: Created
# Post File to Item 367: Created
# Post Geolocation to Item 367: Created
#
# Post Item for Accessible Tourism Guide, 368: Created
# Post File to Item 368: Created
# Post Geolocation to Item 368: Created
#
# Post Item for Accessibility Guide, 369: Created
# Post File to Item 369: Created
# Post Geolocation to Item 369: Created
#
# Post Item for "Blue Line" Map, 370: Created
# Post File to Item 370: Created
# Post Geolocation to Item 370: Created
#
# Post Item for The House Lodging project, 371: Created
# Post File to Item 371: Created
# Post Geolocation to Item 371: Created
#
# Post Item for “Barrier Free Gdynia” as a long-term solution for accessibility, 372: Created
# Post File to Item 372: Created
# Post File to Item 372: Created
# Post Geolocation to Item 372: Created
#
# Post Item for Cross-sectoral table on accessibility and inclusion via P.E.B.A. Plan, 373: Created
# Post File to Item 373: Created
# Post Geolocation to Item 373: Created
#
# Post Item for PEBA – the Plan for the Elimination of Architectural Barriers, 374: Created
# Post File to Item 374: Created
# Post File to Item 374: Created
# Post Geolocation to Item 374: Created
#
# Post Item for Committee and Collaboration for Accessibility in the city, 375: Created
# Post File to Item 375: Created
# Post File to Item 375: Created
# Post Geolocation to Item 375: Created
#
# Post Item for “Accessible Izmir”, 376: Created
# Post File to Item 376: Created
# Post Geolocation to Item 376: Created
#
# Post Item for The Sustainable Urban Mobility Plan 2008-2024, 377: Created
# Post File to Item 377: Created
# Post File to Item 377: Created
# Post Geolocation to Item 377: Created
#
# Post Item for Marco Topo Club, treasure hunt in the city, 378: Created
# Post File to Item 378: Created
# Post File to Item 378: Created
# Post Geolocation to Item 378: Created
#
# Post Item for DESTI-SMART Project, 379: Created
# Post File to Item 379: Created
# Post File to Item 379: Created
# Post Geolocation to Item 379: Created
#
# Post Item for Re-Thinkers Program, 380: Created
# Post File to Item 380: Created
# Post Geolocation to Item 380: Created
#
# Post Item for Autism Life Center, 381: Created
# Post File to Item 381: Created
# Post File to Item 381: Created
# Post Geolocation to Item 381: Created
#
# Post Item for “Just a Minute” Card and commitment to accessibility, 382: Created
# Post File to Item 382: Created
# Post File to Item 382: Created
# Post Geolocation to Item 382: Created
#
# Post Item for Taranto Capital of the Sea, 383: Created
# Post File to Item 383: Created
# Post File to Item 383: Created
# Post Geolocation to Item 383: Created
#
# Post Item for Emphasis on accessibility in Typhlological Museum, 384: Created
# Post File to Item 384: Created
# Post Geolocation to Item 384: Created
#
# Post Item for Smart learning about the city in advance, 385: Created
# Post File to Item 385: Created
# Post File to Item 385: Created
# Post Geolocation to Item 385: Created
#
# Post Item for Digital products tailored for disabled people, 386: Created
# Post File to Item 386: Created
# Post File to Item 386: Created
# Post Geolocation to Item 386: Created
#
# Post Item for Digital Passenger Information via website, 387: Created
# Post File to Item 387: Created
# Post Geolocation to Item 387: Created
#
# Post Item for Sensorial Routes, 388: Created
# Post File to Item 388: Created
# Post File to Item 388: Created
# Post Geolocation to Item 388: Created
#
# Post Item for "Dialog Through Touch" Project, 389: Created
# Post File to Item 389: Created
# Post Geolocation to Item 389: Created
#
# Post Item for Augmented and Virtual Realityhighlights, 390: Created
# Post File to Item 390: Created
# Post Geolocation to Item 390: Created
#
# Post Item for "Sevilla Smart Accessibility Tourist and Events" project and Seville Accessible App, 391: Created
# Post File to Item 391: Created
# Post Geolocation to Item 391: Created
#
# Post Item for Innovative Signage makes world of colour accessible to colour blind, 392: Created
# Post File to Item 392: Created
# Post Geolocation to Item 392: Created
#
# Post Item for Accessible Routes System (SIA), 393: Created
# Post File to Item 393: Created
# Post Geolocation to Item 393: Created
#
# Post Item for "Accessible Zagreb" App and Map, 394: Created
# Post File to Item 394: Created
# Post Geolocation to Item 394: Created
#
# Post Item for Getting around with eco-friendly transport options, 395: Created
# Post File to Item 395: Created
# Post Geolocation to Item 395: Created
#
# Post Item for Pedibus and Bicibus Project, 396: Created
# Post File to Item 396: Created
# Post File to Item 396: Created
# Post Geolocation to Item 396: Created
#
# Post Item for Single City Card for All, 397: Created
# Post File to Item 397: Created
# Post Geolocation to Item 397: Created
#
# Post Item for CO2-neutral by 2030, 398: Created
# Post File to Item 398: Created
# Post Geolocation to Item 398: Created
#
# Post Item for Project ‘Living Lab’ for a more sustainable city, 399: Created
# Post File to Item 399: Created
# Post Geolocation to Item 399: Created
#
# Post Item for The Porto Climate Pact, 400: Created
# Post File to Item 400: Created
# Post File to Item 400: Created
# Post Geolocation to Item 400: Created
#
# Post Item for Sustainable Energy Action Plan, 401: Created
# Post File to Item 401: Created
# Post Geolocation to Item 401: Created
#
# Post Item for Development of Sustainability Strategy, 402: Created
# Post File to Item 402: Created
# Post Geolocation to Item 402: Created
#
# Post Item for “Gdynia Development Strategy 2030” for sustainability and air quality monitoring, 403: Created
# Post File to Item 403: Created
# Post Geolocation to Item 403: Created
#
# Post Item for Plans for a sustainable city, 404: Created
# Post File to Item 404: Created
# Post Geolocation to Item 404: Created
#
# Post Item for Plan8, 405: Created
# Post File to Item 405: Created
# Post Geolocation to Item 405: Created
#
# Post Item for Szeged Sustainable Energy and Climate Plan, 406: Created
# Post File to Item 406: Created
# Post Geolocation to Item 406: Created
#
# Post Item for Smart Water Management Project, 407: Created
# Post File to Item 407: Created
# Post Geolocation to Item 407: Created
#
# Post Item for LIFE WATERCOOL, 408: Created
# Post File to Item 408: Created
# Post Geolocation to Item 408: Created
#
# Post Item for The Zero Plastik Programme, to improve waste management, 409: Created
# Post File to Item 409: Created
# Post File to Item 409: Created
# Post Geolocation to Item 409: Created
#
# Post Item for eCity Sevilla Pilot Project, 410: Created
# Post File to Item 410: Created
# Post Geolocation to Item 410: Created
#
# Post Item for "Close to the City, Close to the Heart / Around Zagreb" Campaign, 411: Created
# Post File to Item 411: Created
# Post Geolocation to Item 411: Created
#
# Post Item for Park of Music and Singing Trees, 412: Created
# Post File to Item 412: Created
# Post Geolocation to Item 412: Created
#
# Post Item for Sustainable Energy and Climate Action Plan, 413: Created
# Post File to Item 413: Created
# Post Geolocation to Item 413: Created
#
# Post Item for Egholm Eco-Island, 414: Created
# Post File to Item 414: Created
# Post Geolocation to Item 414: Created
#
# Post Item for Biosphere Certification, 415: Created
# Post File to Item 415: Created
# Post Geolocation to Item 415: Created
#
# Post Item for Blue Flags Beaches, 416: Created
# Post File to Item 416: Created
# Post File to Item 416: Created
# Post Geolocation to Item 416: Created
#
# Post Item for Thermal Waters - İmamköy Recreation Area, 417: Created
# Post File to Item 417: Created
# Post File to Item 417: Created
# Post Geolocation to Item 417: Created
#
# Post Item for CLIMATic City Centre for the improvement of public spaces, 418: Created
# Post File to Item 418: Created
# Post File to Item 418: Created
# Post Geolocation to Item 418: Created
#
# Post Item for Greening of buildings and spaces, 419: Created
# Post File to Item 419: Created
# Post Geolocation to Item 419: Created
#
# Post Item for Green Belt Project, 420: Created
# Post File to Item 420: Created
# Post File to Item 420: Created
# Post Geolocation to Item 420: Created
#
# Post Item for Full Adaptive Junction System, 421: Created
# Post File to Item 421: Created
# Post File to Item 421: Created
# Post Geolocation to Item 421: Created
#
# Post Item for Green Conference and Event Handbook, 422: Created
# Post File to Item 422: Created
# Post File to Item 422: Created
# Post Geolocation to Item 422: Created
#
# Post Item for Sustainable Event Management, 423: Created
# Post File to Item 423: Created
# Post Geolocation to Item 423: Created
#
# Post Item for Ocean Race Project, 424: Created
# Post File to Item 424: Created
# Post File to Item 424: Created
# Post Geolocation to Item 424: Created
#
# Post Item for Responsible Tourism Festival, 425: Created
# Post File to Item 425: Created
# Post Geolocation to Item 425: Created
#
# Post Item for Green San Sebastián Guide, 426: Created
# Post File to Item 426: Created
# Post File to Item 426: Created
# Post Geolocation to Item 426: Created
#
# Post Item for Sounds of Kleos App, 427: Created
# Post File to Item 427: Created
# Post Geolocation to Item 427: Created
#
# Post Item for AntBis App, 428: Created
# Post File to Item 428: Created
# Post File to Item 428: Created
# Post Geolocation to Item 428: Created
#
# Post Item for Sustainable Transports via share scheme, 429: Created
# Post File to Item 429: Created
# Post File to Item 429: Created
# Post Geolocation to Item 429: Created
#
# Post Item for Cycle Path Network via ESSEN.Erfahren App, 430: Created
# Post File to Item 430: Created
# Post File to Item 430: Created
# Post Geolocation to Item 430: Created
#
# Post Item for “Like Bike” Friendly City, 431: Created
# Post File to Item 431: Created
# Post Geolocation to Item 431: Created
#
# Post Item for Green transport via Lublin City Bike and canoe trips, 432: Created
# Post File to Item 432: Created
# Post File to Item 432: Created
# Post Geolocation to Item 432: Created
#
# Post Item for Smart Cycling in Cyprus, 433: Created
# Post File to Item 433: Created
# Post Geolocation to Item 433: Created
#
# Post Item for Sustainable Tourism Mobility Committee, 434: Created
# Post File to Item 434: Created
# Post File to Item 434: Created
# Post Geolocation to Item 434: Created
#
# Post Item for Encouraging a new form of mobility, 435: Created
# Post File to Item 435: Created
# Post Geolocation to Item 435: Created
#
# Post Item for Sustainable Urban Mobility Plan (SUMP), 436: Created
# Post File to Item 436: Created
# Post Geolocation to Item 436: Created
#
# Post Item for DETECt Aarhus App, 437: Created
# Post File to Item 437: Created
# Post File to Item 437: Created
# Post File to Item 437: Created
# Post Geolocation to Item 437: Created
#
# Post Item for Metrominuto Tour and Maps, 438: Created
# Post File to Item 438: Created
# Post Geolocation to Item 438: Created
#
# Post Item for Rollindagando (Cultural Mapping of the Old Town), 439: Created
# Post File to Item 439: Created
# Post File to Item 439: Created
# Post Geolocation to Item 439: Created
#
# Post Item for Smart App for infos to the Historical Unesco Park, 440: Created
# Post File to Item 440: Created
# Post Geolocation to Item 440: Created
#
# Post Item for QR Codes for Creative City Tour, 441: Created
# Post File to Item 441: Created
# Post Geolocation to Item 441: Created
#
# Post Item for World Heritage App and Portal, 442: Created
# Post File to Item 442: Created
# Post Geolocation to Item 442: Created
#
# Post Item for Augmented Reality of Zeugma Ancient City, 443: Created
# Post File to Item 443: Created
# Post Geolocation to Item 443: Created
#
# Post Item for Augmented Reality Routes, 444: Created
# Post File to Item 444: Created
# Post File to Item 444: Created
# Post Geolocation to Item 444: Created
#
# Post Item for "Tourist Lublin" App and AR, 445: Created
# Post File to Item 445: Created
# Post File to Item 445: Created
# Post Geolocation to Item 445: Created
#
# Post Item for Myth of Aphrodite App & AR Experience, 446: Created
# Post File to Item 446: Created
# Post File to Item 446: Created
# Post File to Item 446: Created
# Post Geolocation to Item 446: Created
#
# Post Item for AR, VR, and 3D Reconstruction of the Alcazar of Seville, 447: Created
# Post File to Item 447: Created
# Post Geolocation to Item 447: Created
#
# Post Item for as a comprehensive guide, 448: Created
# Post File to Item 448: Created
# Post File to Item 448: Created
# Post Geolocation to Item 448: Created
#
# Post Item for “Tomis” Tablets as an information panel for public use, 449: Created
# Post File to Item 449: Created
# Post Geolocation to Item 449: Created
#
# Post Item for Making suggestions to visitors via “TPnP Tomi Go Matosinhos” App, 450: Created
# Post File to Item 450: Created
# Post Geolocation to Item 450: Created
#
# Post Item for Smart Port for Integrated Urban Management, 451: Created
# Post File to Item 451: Created
# Post Geolocation to Item 451: Created
#
# Post Item for Smart Gateway for smart solutions and solving challenges, 452: Created
# Post File to Item 452: Created
# Post Geolocation to Item 452: Created
#
# Post Item for CONNECTED ESSEN, 453: Created
# Post File to Item 453: Created
# Post Geolocation to Item 453: Created
#
# Post Item for Gijón Smart Cities Knowledge Chair, 454: Created
# Post File to Item 454: Created
# Post Geolocation to Item 454: Created
#
# Post Item for The Integrated Connectivity System, 455: Created
# Post File to Item 455: Created
# Post Geolocation to Item 455: Created
#
# Post Item for Smart Kalea Platform, data for city management, 456: Created
# Post File to Item 456: Created
# Post File to Item 456: Created
# Post Geolocation to Item 456: Created
#
# Post Item for Safety Circle Project, 457: Created
# Post File to Item 457: Created
# Post File to Item 457: Created
# Post Geolocation to Item 457: Created
#
# Post Item for Destination Hub. Ruhr, 458: Created
# Post File to Item 458: Created
# Post Geolocation to Item 458: Created
#
# Post Item for Gijón Data Lab, Tool for the accommodation sector, 459: Created
# Post File to Item 459: Created
# Post Geolocation to Item 459: Created
#
# Post Item for Fiware, 460: Created
# Post File to Item 460: Created
# Post Geolocation to Item 460: Created
#
# Post Item for The Realization of the Taranto Ecosystem Platform, 461: Created
# Post File to Item 461: Created
# Post File to Item 461: Created
# Post Geolocation to Item 461: Created
#
# Post Item for Zagreb Smart City Hub, 462: Created
# Post File to Item 462: Created
# Post Geolocation to Item 462: Created
#
# Post Item for ‘Virtual Clerk’ as an Artificial Intelligence Tool, 463: Created
# Post File to Item 463: Created
# Post Geolocation to Item 463: Created
#
# Post Item for Internet Week Denmark, 464: Created
# Post File to Item 464: Created
# Post Geolocation to Item 464: Created
#
# Post Item for Digital Art Experiences, 465: Created
# Post File to Item 465: Created
# Post Geolocation to Item 465: Created
#
# Post Item for EFEDERS Digital Education Platform, 466: Created
# Post File to Item 466: Created
# Post File to Item 466: Created
# Post Geolocation to Item 466: Created
#
# Post Item for The Fairy Tale Castle, in a thematic park, 467: Created
# Post File to Item 467: Created
# Post Geolocation to Item 467: Created
#
# Post Item for “ReinventaPorto” Project, 468: Created
# Post File to Item 468: Created
# Post File to Item 468: Created
# Post Geolocation to Item 468: Created
#
# Post Item for MEB, all museum offers in one place, 469: Created
# Post File to Item 469: Created
# Post Geolocation to Item 469: Created
#
# Post Item for A SmART City Vocation, 470: Created
# Post File to Item 470: Created
# Post Geolocation to Item 470: Created
#
# Post Item for First Autonomous Busses in Denmark, 471: Created
# Post File to Item 471: Created
# Post Geolocation to Item 471: Created
#
# Post Item for Smart Stations Project, 472: Created
# Post File to Item 472: Created
# Post File to Item 472: Created
# Post Geolocation to Item 472: Created
#
# Post Item for Smart Public Transportation System, 473: Created
# Post File to Item 473: Created
# Post File to Item 473: Created
# Post Geolocation to Item 473: Created
#
# Post Item for Smart Parking System, 474: Created
# Post File to Item 474: Created
# Post File to Item 474: Created
# Post File to Item 474: Created
# Post Geolocation to Item 474: Created
#
# Post Item for SASMob, 475: Created
# Post File to Item 475: Created
# Post Geolocation to Item 475: Created
#
# Post Item for The European Region of Gastronomy, 476: Created
# Post File to Item 476: Created
# Post File to Item 476: Created
# Post Geolocation to Item 476: Created
#
# Post Item for Thinking Sustainably Gastronomy Festival, 477: Created
# Post File to Item 477: Created
# Post Geolocation to Item 477: Created
#
# Post Item for Pafos Aphrodite Festival, 478: Created
# Post File to Item 478: Created
# Post File to Item 478: Created
# Post Geolocation to Item 478: Created
#
# Post Item for Taranto Regeneration Urban and Street, 479: Created
# Post File to Item 479: Created
# Post File to Item 479: Created
# Post Geolocation to Item 479: Created
#
# Post Item for European Cultural Route, 480: Created
# Post File to Item 480: Created
# Post Geolocation to Item 480: Created
#
# Post Item for Experiential Tourism, to discover the city, 481: Created
# Post File to Item 481: Created
# Post Geolocation to Item 481: Created
#
# Post Item for Seville “Creative City of Music” by UNESCO, 482: Created
# Post File to Item 482: Created
# Post Geolocation to Item 482: Created
#
# Post Item for Dokk1 Library, 483: Created
# Post File to Item 483: Created
# Post File to Item 483: Created
# Post Geolocation to Item 483: Created
#
# Post Item for Theatres with a unique location, 484: Created
# Post File to Item 484: Created
# Post File to Item 484: Created
# Post Geolocation to Item 484: Created
#
# Post Item for Tabakalera, a contemporary culture centre in a former tobacco factory, 485: Created
# Post File to Item 485: Created
# Post File to Item 485: Created
# Post Geolocation to Item 485: Created
#
# Post Item for Recovery of the environment and the complex Fabrica de Artilleria, 486: Created
# Post File to Item 486: Created
# Post Geolocation to Item 486: Created
#
# Post Item for Kirk Gallery and Street Art, 487: Created
# Post File to Item 487: Created
# Post Geolocation to Item 487: Created
#
# Post Item for Street Art Walking Tour, 488: Created
# Post File to Item 488: Created
# Post Geolocation to Item 488: Created
#
# Post Item for Public Light Weeks, 489: Created
# Post File to Item 489: Created
# Post File to Item 489: Created
# Post Geolocation to Item 489: Created
#
# Post Item for Local Communities Showcasing Art Together, 490: Created
# Post File to Item 490: Created
# Post File to Item 490: Created
# Post Geolocation to Item 490: Created
#
# Post Item for Teatro Stabile del Veneto “Carlo Goldoni”, 491: Created
# Post File to Item 491: Created
# Post Geolocation to Item 491: Created
#
# Post Item for Old Town Festival, 492: Created
# Post File to Item 492: Created
# Post File to Item 492: Created
# Post Geolocation to Item 492: Created
#
# Post Item for Culrutas, twelve perspectives to discover the city, 493: Created
# Post File to Item 493: Created
# Post File to Item 493: Created
# Post Geolocation to Item 493: Created
#
# Post Item for Haller Youth Centre, when cultural heritage meets creativity, 494: Created
# Post File to Item 494: Created
# Post File to Item 494: Created
# Post Geolocation to Item 494: Created
#
# Post Item for Experyment Science Centre for learning experiences, 495: Created
# Post File to Item 495: Created
# Post File to Item 495: Created
# Post Geolocation to Item 495: Created
#
# Post Item for GenovaJeans, 496: Created
# Post File to Item 496: Created
# Post Geolocation to Item 496: Created
#
# Post Item for Super Walls Event, Sustainable Street Art, 497: Created
# Post File to Item 497: Created
# Post Geolocation to Item 497: Created
#
# Post Item for Seville & Me, 498: Created
# Post File to Item 498: Created
# Post Geolocation to Item 498: Created
#
# Post Item for Culture and Creativity Strategy, 499: Created
# Post File to Item 499: Created
# Post Geolocation to Item 499: Created
#
# Post Item for Community Engagement, 500: Created
# Post File to Item 500: Created
# Post File to Item 500: Created
# Post Geolocation to Item 500: Created
#
# Post Item for The Rolli Lab, 501: Created
# Post File to Item 501: Created
# Post File to Item 501: Created
# Post Geolocation to Item 501: Created
#
# Post Item for Gijonomía, 502: Created
# Post File to Item 502: Created
# Post File to Item 502: Created
# Post Geolocation to Item 502: Created
#
# Post Item for Euskadi Tourism Code of Ethics, 503: Created
# Post File to Item 503: Created
# Post File to Item 503: Created
# Post Geolocation to Item 503: Created
